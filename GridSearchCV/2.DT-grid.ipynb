# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int)
dataset=dataset.drop(columns=["sex_male","smoker_yes"])
dataset
# Out:
#       age     bmi  children      charges  sex_female  smoker_no
# 0      19  27.900         0  16884.92400           1          0
# 1      18  33.770         1   1725.55230           0          1
# 2      28  33.000         3   4449.46200           0          1
# 3      33  22.705         0  21984.47061           0          1
# 4      32  28.880         0   3866.85520           0          1
# ...   ...     ...       ...          ...         ...        ...
# 1333   50  30.970         3  10600.54830           0          1
# 1334   18  31.920         0   2205.98080           1          1
# 1335   18  36.850         0   1629.83350           1          1
# 1336   21  25.800         0   2007.94500           1          1
# 1337   61  29.070         0  29141.36030           1          0
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_female', 'smoker_no'], dtype='object')

# %%
indep= dataset[['age', 'bmi', 'children', 'sex_female', 'smoker_no']]
indep
# Out:
#       age     bmi  children  sex_female  smoker_no
# 0      19  27.900         0           1          0
# 1      18  33.770         1           0          1
# 2      28  33.000         3           0          1
# 3      33  22.705         0           0          1
# 4      32  28.880         0           0          1
# ...   ...     ...       ...         ...        ...
# 1333   50  30.970         3           0          1
# 1334   18  31.920         0           1          1
# 1335   18  36.850         0           1          1
# 1336   21  25.800         0           1          1
# 1337   61  29.070         0           1          0
#
# [1338 rows x 5 columns]

# %%
dep=dataset[['charges']]
dep
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid ={'criterion':['poisson','squared_error','friedman_mse','absolute_error'],
             'splitter':['random','best'],'max_features':['sqrt','log2','int']}

grid = GridSearchCV ( DecisionTreeRegressor(), param_grid, refit= True, verbose = 3, n_jobs = -1 )

grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Gowri\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Gowri\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Gowri\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Gowri\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
# ...

# %%
#print best parameters after tunning
#print(grid.best_params_)
print( "The R_Score value for best parameter{}".format(grid.best_params_))
# Out:
# The R_Score value for best parameter{'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}

# %%
re=grid.cv_results_

print( "The R_Score value for best parameter{}".format(grid.best_params_))
# Out:
# The R_Score value for best parameter{'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002016      0.004033         0.002001        0.004001
# 1        0.004093      0.004886         0.002009        0.004017
# 2        0.002009      0.004019         0.002015        0.004031
# 3        0.008123      0.004062         0.002016        0.004033
# 4        0.002013      0.004025         0.000000        0.000000
# 5        0.002001      0.004002         0.000000        0.000000
# 6        0.002227      0.004177         0.002013        0.004026
# 7        0.006038      0.004930         0.000000        0.000000
# 8        0.004324      0.004675         0.002646        0.003749
# 9        0.004647      0.005691         0.004157        0.005098
# 10       0.000000      0.000000         0.000000        0.000000
# 11       0.002001      0.004002         0.000000        0.000000
# 12       0.000310      0.000380         0.004028        0.004933
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_female_input=int(input("sex_female:"))
smoker_no_input=int(input("smoker_no:"))
# Out:
# Age: 30
# BMI: 26
# Children: 1
# sex_female: 0
# smoker_no: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_female_input,smoker_no_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[19199.944]
# C:\Gowri\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
